# %% [markdown]
# <a href="https://colab.research.google.com/github/brunopersy/botlinkedin/blob/master/Estat%C3%ADstica_com_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import random
numeros_aleatorios =[random.randint(0,9) for _ in range(400)]

# %% [markdown]
# #TABELA DE AMOSTRAGEM(MÉTODO ANTIGO)

# %%
largura_maxima = 2

def formatar_tabela(numeros, num_por_linha = 20, largura = largura_maxima):
  for i in range(0, len(numeros), num_por_linha):
    linha = numeros[i:i+num_por_linha]
    print(*[str(num).rjust(largura)for num in linha])

formatar_tabela(numeros_aleatorios)
# Out:
#  9  1  4  1  7  7  7  6  3  1  7  0  6  6  9  0  7  4  3  9
#  1  5  0  0  0  8  0  6  3  6  0  8  3  7  7  8  3  5  3  3
#  7  4  0  6  8  1  2  4  1  5  8  6  8  3  4  4  9  7  8  6
#  9  0  7  3  6  6  2  5  8  5  1  7  8  1  2  8  6  5  7  0
#  7  0  4  9  9  9  6  2  2  8  3  0  3  8  8  3  6  8  5  9
#  5  7  4  8  9  0  6  8  2  8  8  3  6  0  7  5  9  8  3  8
#  6  7  5  6  5  0  8  8  9  9  5  7  9  0  3  2  8  9  2  1
#  8  4  0  1  1  0  7  0  4  3  4  1  9  2  5  4  1  2  2  4
#  8  2  4  4  7  5  7  7  1  0  4  6  5  6  3  4  1  4  8  3
#  9  6  0  3  0  6  2  0  2  7  8  6  8  3  8  7  3  8  0  6
#  9  5  6  0  4  2  3  0  4  1  1  4  4  2  6  9  4  2  0  8
#  0  9  3  9  7  2  9  8  0  6  3  5  1  3  9  6  9  3  7  1
#  6  4  8  7  0  5  9  6  4  0  2  3  5  9  2  5  6  3  4  1
#  6  8  5  8  7  8  3  1  0  1  2  2  2  8  3  4  5  9  8  4
#  5  5  5  1  4  3  9  7  2  9  8  1  5  0  6  1  6  2  2  5
#  1  9  9  6  1  9  8  3  9  1  4  5  4  9  8  1  7  4  1  0
# ...

# %% [markdown]
# #CARREGANDO DADOS

# %%
dataset = pd.read_csv('/census.csv')
#pd.read_csv = lê o dataset

# %%
dataset.shape
#Shape = (mostra a quantidade de linhas e colunas do dataset)
# Out:
# (32561, 15)

# %%
dataset.head()
#Head = (mostra as 5 'primeiras linhas do dataset)
# Out:
#    age          workclass  final-weight   education  education-num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loos  hour-per-week  native-country  income
# ...

# %%
dataset.tail()
#Tail = (mostra as 5 'ultimas linhas do dataset)
# Out:
#        age      workclass  final-weight    education  education-num  \
# 32556   27        Private        257302   Assoc-acdm             12
# 32557   40        Private        154374      HS-grad              9
# 32558   58        Private        151910      HS-grad              9
# 32559   22        Private        201490      HS-grad              9
# 32560   52   Self-emp-inc        287927      HS-grad              9
#
#             marital-status          occupation relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital-gain  capital-loos  hour-per-week  native-country  income
# ...

# %% [markdown]
# #AMOSTRAGEM ALEATÓRIA SIMPLES

# %%
df_amostra_aleatoria_simples = dataset.sample(n = 100)
df_amostra_aleatoria_simples.shape
# Out:
# (100, 15)

# %%
df_amostra_aleatoria_simples.head()
# Out:
#        age          workclass  final-weight   education  education-num  \
# 11277   28            Private        214385   Assoc-voc             11
# 19833   47            Private        192053     HS-grad              9
# 19531   39       Self-emp-inc        135500     HS-grad              9
# 27594   26            Private        339324     HS-grad              9
# 28186   35   Self-emp-not-inc        238802     HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 11277        Never-married     Exec-managerial       Own-child   Black
# 19833             Divorced    Transport-moving   Not-in-family   White
# 19531   Married-civ-spouse     Exec-managerial         Husband   White
# 27594   Married-civ-spouse   Machine-op-inspct         Husband   White
# 28186   Married-civ-spouse     Farming-fishing         Husband   White
#
#            sex  capital-gain  capital-loos  hour-per-week  native-country  \
# ...

# %%
def amostragem_aleatoria_simples(dataset, amostras):
  return dataset.sample(n = amostras, random_state=1)

# %%
df_amostra_aleatoria_simples = amostragem_aleatoria_simples(dataset, 100)
df_amostra_aleatoria_simples.shape
# Out:
# (100, 15)

# %%
df_amostra_aleatoria_simples.head()
# Out:
#        age          workclass  final-weight   education  education-num  \
# 9646    62   Self-emp-not-inc         26911     7th-8th              4
# 709     18            Private        208103        11th              7
# 7385    25            Private        102476   Bachelors             13
# 16671   33            Private        511517     HS-grad              9
# 21932   36            Private        292570        11th              7
#
#             marital-status          occupation     relationship    race  \
# 9646               Widowed       Other-service    Not-in-family   White
# 709          Never-married       Other-service   Other-relative   White
# 7385         Never-married     Farming-fishing        Own-child   White
# 16671   Married-civ-spouse      Prof-specialty          Husband   White
# 21932        Never-married   Machine-op-inspct        Unmarried   White
#
#            sex  capital-gain  capital-loos  hour-per-week  native-country  \
# ...

# %% [markdown]
# #Amostragem Sistemática

# %%
dataset.shape
# Out:
# (32561, 15)

# %%
len(dataset) // 100
# Out:
# 325

# %%
random.seed(1)
random.randint(0,325)
# Out:
# 68

# %%
68 + 325
# Out:
# 393

# %%
393 + 325
# Out:
# 718

# %%
np.arange(68, len(dataset), step = 325)
# Out:
# array([   68,   393,   718,  1043,  1368,  1693,  2018,  2343,  2668,
#         2993,  3318,  3643,  3968,  4293,  4618,  4943,  5268,  5593,
#         5918,  6243,  6568,  6893,  7218,  7543,  7868,  8193,  8518,
#         8843,  9168,  9493,  9818, 10143, 10468, 10793, 11118, 11443,
#        11768, 12093, 12418, 12743, 13068, 13393, 13718, 14043, 14368,
#        14693, 15018, 15343, 15668, 15993, 16318, 16643, 16968, 17293,
#        17618, 17943, 18268, 18593, 18918, 19243, 19568, 19893, 20218,
#        20543, 20868, 21193, 21518, 21843, 22168, 22493, 22818, 23143,
#        23468, 23793, 24118, 24443, 24768, 25093, 25418, 25743, 26068,
#        26393, 26718, 27043, 27368, 27693, 28018, 28343, 28668, 28993,
#        29318, 29643, 29968, 30293, 30618, 30943, 31268, 31593, 31918,
#        32243])
